# %%
# import os
import pickle

def dump_item(this_item, path):
    open_file = open(path, "wb")
    pickle.dump(this_item, open_file)
    open_file.close()

# %%
h_min,h_max=131.5, 160.8
w_min, w_max=64.2, 78.1
#1.68~2.5047
fillet_min, fillet_max=9.5, 12
mute_min, mute_max=5.19, 5.65
mute2top_min, mute2top_max=21.96, 33.27
power_min, power_max=15.56, 18.05
power2top_min, power2top_max=30.91, 53.66
mute2vol_min, mute2vol_max=12.11, 13.3
vol_min, vol_max=9.76, 10.91
vol_gap_min, vol_gap_max=12.26, 14.01
notch_r1_min, notch_r1_max=0.82, 1.14
vshift_min, vshift_max=0, 1
notch_r2_min, notch_r2_max=2.56, 4
notch_h_min, notch_h_max=7.29, 9.2
notch_w_min, notch_w_max=26.86, 36.79
button_t_min, button_t_max=0.4, 0.59
scr2pl_min, scr2pl_max=2.17, 4.2
pl2edge_min, pl2edge_max=1, 1.5
stripe_w_min, stripe_w_max=1, .51
stripe2top_min, stripe2top_max=12.81, 16.51
stripe2low_min, stripe2low_max=12.81, 16.51
stripe_ur_min, stripe_ur_max=13.13, 16.38
stripe_ll_min, stripe_ll_max=13.13, 16.38

ringr_min, ringr_max = 0.5, 0.77
ringd_min, ringd_max = 5.79, 8.1
ringd2_min, ringd2_max = 5.79, 10.34#when speaker is upper
lens_min, lens_max = 0.9, 1.88
lens1p_min, lens1p_max = 0.101838, 0.14264432
lens2p_min1, lens2p_max1= 0.265, 0.29
lens2p2=0.4185
lens3p_min1, lens3p_max1= 0.7, 0.733
lens3p2=0.6323
lens4p_min, lens4p_max = 0.85443, 0.88854

h2w=0.98423
h2fillet=0.642522
h2stripe_ur=0.996595
mute_h2power=0.687735
mute_h2power_h=0.868564
mute_h2vol_gap=0.678879
scr_gap2edge_gap=0.610561
stripe_top2low=0.991767
stripe_top2ll=0.956417

# %%
iphone_par={\
"h_par":{"min":h_min,"max":h_max},\
"w_par":{"min":w_min,"max":w_max},\
"fillet_par":{"min":fillet_min,"max":fillet_max},\
"mute_par":{"min":mute_min,"max":mute_max},\
"mute2top_par":{"min":mute2top_min,"max":mute2top_max},\
"power_par":{"min":power_min,"max":power_max},\
"power2top_par":{"min":power2top_min,"max":power2top_max},\
"mute2vol_par":{"min":mute2vol_min,"max":mute2vol_max},\
"vol_par":{"min":vol_min,"max":vol_max},\
"vol_gap_par":{"min":vol_gap_min,"max":vol_gap_max},\
"notch_r1_par":{"min":notch_r1_min,"max":notch_r1_max},\
"vshift_par":{"min":vshift_min,"max":vshift_max},\
"notch_r2_par":{"min":notch_r2_min,"max":notch_r2_max},\
"notch_h_par":{"min":notch_h_min,"max":notch_h_max},\
"notch_w_par":{"min":notch_w_min,"max":notch_w_max},\
"button_t_par":{"min":button_t_min,"max":button_t_max},\
"scr2pl_par":{"min":scr2pl_min,"max":scr2pl_max},\
"pl2edge_par":{"min":pl2edge_min,"max":pl2edge_max},\
"stripe_w_par":{"min":stripe_w_min,"max":stripe_w_max},\
"stripe2top_par":{"min":stripe2top_min,"max":stripe2top_max},\
"stripe2low_par":{"min":stripe2low_min,"max":stripe2low_max},\
"stripe_ur_par":{"min":stripe_ur_min,"max":stripe_ur_max},\
"stripe_ll_par":{"min":stripe_ll_min,"max":stripe_ll_max},\
"ringr_par":{"min":ringr_min,"max":ringr_max},\
"ringd_par":{"min":ringd_min,"max":ringd_max},\
"ringd2_par":{"min":ringd2_min,"max":ringd2_max},\
"lens_par":{"min":lens_min,"max":lens_max},\
"lens1p_par":{"min":lens1p_min,"max":lens1p_max},\
"lens2p_par":{"min":lens2p_min1,"max":lens2p_max1},\
"lens3p_par":{"min":lens3p_min1,"max":lens3p_max1},\
"lens4p_par":{"min":lens4p_min,"max":lens4p_max},\
"lens2p2":lens2p2,
"lens3p2":lens3p2,       
"h2w":h2w,            
"h2fillet":h2fillet,            
"h2stripe_ur":h2stripe_ur,            
"mute_h2power":mute_h2power,            
"mute_h2power_h":mute_h2power_h,            
"mute_h2vol_gap":mute_h2vol_gap,            
"scr_gap2edge_gap":scr_gap2edge_gap,            
"stripe_top2low":stripe_top2low,            
"stripe_top2ll":stripe_top2ll,
            
}

# %%
dump_item(iphone_par,"iphone_par.pkl")

# %%
h_min, h_max=142.2, 166.9
w_min, w_max=69.1, 77.1
rl_min, rl_max=6.52, 8.31
rm_min, rm_max=6.52, 8.03
m_ushift_min, m_ushift_max=0,1.76
m_lshift_min, m_lshift_max=0,2.44
rs_min, rs_max=4.89, 6.97
sux_min, sux_max=-0.37, 1.33
suh_min, suh_max=-0.76, 0.86
slh_min, slh_max=0.41, 1.97
camera_r_h_min, camera_r_h_max=7.82, 8.01 #right height
camera2r_min, camera2r_max=7.79, 9.96
camera_d_min, camera_d_max=7.29, 11.03 #if exist
camera_r1_min, camera_r1_max=2.47, 2.49
camera_r2_min, camera_r2_max=1.59, 1.63
ring_min, ring_max=2.36, 2.65
camera_m_h_min, camera_m_h_max=5.23, 5.37 #middle height
camera_m_r_min, camera_m_r_max=1.81, 1.98
trap_u_min, trap_u_max=12.45, 13.56
trap_l_min, trap_l_max=8.51, 10.5
trap_h_ratio_min, trap_h_ratio_max=0.1, 1
vol_l_min, vol_l_max=19.25, 20.04
vol_h_min, vol_h_max=28.76, 41.8
bixby_l_min, bixby_l_max=7.86, 10.22
bixby_h_min, bixby_h_max=50.16,65.69
power_free_h_min, power_free_h_max=26.76, 51.57
power_unfree_h_min, power_unfree_h_max=61.52, 66.38
power_l_min, power_l_max=10.03, 14.88
button_h=0.75

# %%
samsung_par={
"h_par":{"min":h_min,"max":h_max},\
"w_par":{"min":w_min,"max":w_max},\
"rl_par":{"min":rl_min,"max":rl_max},\
"rm_par":{"min":rm_min,"max":rm_max},\
"m_ushift_par":{"min":m_ushift_min,"max":m_ushift_max},\
"m_lshift_par":{"min":m_lshift_min,"max":m_lshift_max},\
"rs_par":{"min":rs_min,"max":rs_max},\
"sux_par":{"min":sux_min,"max":sux_max},\
"suh_par":{"min":suh_min,"max":suh_max},\
"slh_par":{"min":slh_min,"max":slh_max},\
"camera_r_h_par":{"min":camera_r_h_min,"max":camera_r_h_max},\
"camera2r_par":{"min":camera2r_min,"max":camera2r_max},\
"camera_d_par":{"min":camera_d_min,"max":camera_d_max},\
"camera_r1_par":{"min":camera_r1_min,"max":camera_r1_max},\
"camera_r2_par":{"min":camera_r2_min,"max":camera_r2_max},\
"ring_par":{"min":ring_min,"max":ring_max},\
"camera_m_h_par":{"min":camera_m_h_min,"max":camera_m_h_max},\
"camera_m_r_par":{"min":camera_m_r_min,"max":camera_m_r_max},\
"trap_u_par":{"min":trap_u_min,"max":trap_u_max},\
"trap_l_par":{"min":trap_l_min,"max":trap_l_max},\
"trap_h_ratio_par":{"min":trap_h_ratio_min,"max":trap_h_ratio_max},\
"vol_l_par":{"min":vol_l_min,"max":vol_l_max},\
"vol_h_par":{"min":vol_h_min,"max":vol_h_max},\
"bixby_l_par":{"min":bixby_l_min,"max":bixby_l_max},\
"bixby_h_par":{"min":bixby_h_min,"max":bixby_h_max},\
"power_free_h_par":{"min":power_free_h_min,"max":power_free_h_max},\
"power_unfree_h_par":{"min":power_unfree_h_min,"max":power_unfree_h_max},\
"power_l_par":{"min":power_l_min,"max":power_l_max},\
"button_h_par":button_h
}

# %%
dump_item(samsung_par,"samsung_par.pkl")
